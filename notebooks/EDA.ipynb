# %% [markdown]
# ## Diamond Price Prediction

# %% [markdown]
# ### Introduction About the Data :
#
# **The dataset** The goal is to predict `price` of given diamond (Regression Analysis).
#
# There are 10 independent variables (including `id`):
#
# * `id` : unique identifier of each diamond
# * `carat` : Carat (ct.) refers to the unique unit of weight measurement used exclusively to weigh gemstones and diamonds.
# * `cut` : Quality of Diamond Cut
# * `color` : Color of Diamond
# * `clarity` : Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification.
# * `depth` : The depth of diamond is its height (in millimeters) measured from the culet (bottom tip) to the table (flat, top surface)
# * `table` : A diamond's table is the facet which can be seen when the stone is viewed face up.
# * `x` : Diamond X dimension
# * `y` : Diamond Y dimension
# * `x` : Diamond Z dimension
#
# Target variable:
# * `price`: Price of the given Diamond.
#
# Dataset Source Link :
# [https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv](https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv)

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv('Data.csv')

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
#No Null Value

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#No Duplicate Value Present

# %% [markdown]
# #### Carat Column

# %%
df['carat'].describe()
# Out:
# count    193573.000000
# mean          0.790688
# std           0.462688
# min           0.200000
# 25%           0.400000
# 50%           0.700000
# 75%           1.030000
# max           3.500000
# Name: carat, dtype: float64

# %%
sns.boxplot(df['carat'])
# Out:
# <Axes: >

# %%
sns.histplot(x=df['carat'],binwidth=0.5)
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %%
sns.displot(df['carat'], kind='kde')

# %% [markdown]
# #### Cut Column

# %%
df['cut'].value_counts()
# Out:
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: cut, dtype: int64

# %%
sns.countplot(x=df['cut'])
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
## For Domain Purpose https://www.americangemsociety.org/ags-diamond-grading-system/
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

# %%
df['cut']=df['cut'].map(cut_map)

# %% [markdown]
# ##### Color Column

# %%
df['color'].value_counts()
# Out:
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: color, dtype: int64

# %%
sns.countplot(x=df['color'])
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map = {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}

# %%
df['color'] = df['color'].map(color_map)

# %% [markdown]
# #### Clarity Column

# %%
df['clarity'].dtype
# Out:
# dtype('O')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['clarity'].value_counts()
# Out:
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: clarity, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(x=df['clarity'])
# Out:
# <Axes: xlabel='clarity', ylabel='count'>

# %%
df['clarity'].describe()
# Out:
# count     193573
# unique         8
# top          SI1
# freq       53272
# Name: clarity, dtype: object

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map = {"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}

# %%
df['clarity'] = df['clarity'].map(clarity_map)

# %% [markdown]
# #### Depth Column

# %%
df['depth'].describe()
# Out:
# count    193573.000000
# mean         61.820574
# std           1.081704
# min          52.100000
# 25%          61.300000
# 50%          61.900000
# 75%          62.400000
# max          71.600000
# Name: depth, dtype: float64

# %%
sns.boxplot(x=df['depth'])
# Out:
# <Axes: xlabel='depth'>

# %%
sns.histplot(x=df['depth'],binwidth=0.5)
# Out:
# <Axes: xlabel='depth', ylabel='Count'>

# %% [markdown]
# #### Table Column

# %%
df['table'].describe()
# Out:
# count    193573.000000
# mean         57.227675
# std           1.918844
# min          49.000000
# 25%          56.000000
# 50%          57.000000
# 75%          58.000000
# max          79.000000
# Name: table, dtype: float64

# %%
sns.boxplot(x=df['table'])
# Out:
# <Axes: xlabel='table'>

# %%
sns.histplot(x=df['table'],binwidth=2)
# Out:
# <Axes: xlabel='table', ylabel='Count'>

# %% [markdown]
# #### X Table

# %%
df['x'].describe()
# Out:
# count    193573.000000
# mean          5.715312
# std           1.109422
# min           0.000000
# 25%           4.700000
# 50%           5.700000
# 75%           6.510000
# max           9.650000
# Name: x, dtype: float64

# %%
df['x'].mode()
# Out:
# 0    4.32
# Name: x, dtype: float64

# %%
sns.boxplot(x=df['x'])
# Out:
# <Axes: xlabel='x'>

# %%
df['x'].median()
# Out:
# 5.7

# %%
sns.histplot(x=df['x'],binwidth=1)
# Out:
# <Axes: xlabel='x', ylabel='Count'>

# %%
sns.displot(df['x'], kind='kde')

# %%
sns.displot(df['x'], kde=True)

# %%
df[df['x']==0]
# Out:
#             id  carat  cut  color  clarity  depth  table    x     y    z  \
# 92703    92703   0.71    2      3        3   64.1   60.0  0.0  0.00  0.0
# 170318  170318   0.71    2      1        4   64.1   60.0  0.0  0.00  0.0
# 178000  178000   0.71    3      3        2   62.0   60.0  0.0  6.71  0.0
#
#         price
# 92703    2130
# 170318    910
# 178000   2130

# %%
import numpy as np

# %%
df['x'].replace(0, np.nan,inplace=True)

# %%
df['x'].fillna(df['x'].median(),inplace=True)

# %%
df[df['x']==0]
# Out:
# Empty DataFrame
# Columns: [id, carat, cut, color, clarity, depth, table, x, y, z, price]
# Index: []

# %% [markdown]
# #### Y Column

# %%
df['y'].describe()
# Out:
# count    193573.000000
# mean          5.720094
# std           1.102333
# min           0.000000
# 25%           4.710000
# 50%           5.720000
# 75%           6.510000
# max          10.010000
# Name: y, dtype: float64

# %%
sns.boxplot(x=df['y'])
# Out:
# <Axes: xlabel='y'>

# %%
sns.histplot(x=df['y'],binwidth=1)
# Out:
# <Axes: xlabel='y', ylabel='Count'>

# %%
sns.displot(df['y'], kind='kde')

# %%
sns.displot(df['y'], kde=True)

# %%
df['y'].replace(0, np.nan,inplace=True)

# %%
df['y'].fillna(df['y'].median(),inplace=True)

# %% [markdown]
# #### Z Column

# %%
df['z'].describe()
# Out:
# count    193573.000000
# mean          3.534246
# std           0.688922
# min           0.000000
# 25%           2.900000
# 50%           3.530000
# 75%           4.030000
# max          31.300000
# Name: z, dtype: float64

# %%
sns.boxplot(x=df['z'])
# Out:
# <Axes: xlabel='z'>

# %%
sns.histplot(x=df['z'],binwidth=1)
# Out:
# <Axes: xlabel='z', ylabel='Count'>

# %%
sns.displot(df['z'], kind='kde')

# %%
sns.displot(df['z'], kde=True)

# %%
df['z'].replace(0, np.nan,inplace=True)

# %%
df['z'].fillna(df['z'].mean(),inplace=True)

# %%
df.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453

# %% [markdown]
# #### Price Column

# %%
df['price'].describe()
# Out:
# count    193573.000000
# mean       3969.155414
# std        4034.374138
# min         326.000000
# 25%         951.000000
# 50%        2401.000000
# 75%        5408.000000
# max       18818.000000
# Name: price, dtype: float64

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
sns.displot(df['price'], kind='kde')

# %%
sns.displot(df['z'], kde=True)

# %%
sns.histplot(x=df['price'],binwidth=1000)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
l=[]
l1=df.columns.to_list()
l1
for i in l1:
  if(df[i].dtypes!='O'):
    l.append(i)
l
# Out:
# ['id',
#  'carat',
#  'cut',
#  'color',
#  'clarity',
#  'depth',
#  'table',
#  'x',
#  'y',
#  'z',
#  'price']

# %%
df.dtypes
# Out:
# id           int64
# carat      float64
# cut          int64
# color        int64
# clarity      int64
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
sns.lineplot(y=df['price'],x=df['carat'])
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.lineplot(y=df['price'],x=df['depth'])
# Out:
# <Axes: xlabel='depth', ylabel='price'>

# %%
sns.lineplot(y=df['price'],x=df['table'])
# Out:
# <Axes: xlabel='table', ylabel='price'>

# %%
sns.scatterplot(data=df, x="carat", y="price", hue="cut")
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df.corr(method='pearson')
# Out:
#                id     carat       cut     color   clarity     depth     table  \
# id       1.000000 -0.000771 -0.001746 -0.001267 -0.003441  0.002647  0.002448
# carat   -0.000771  1.000000 -0.150901  0.292400 -0.348611  0.027852  0.225737
# cut     -0.001746 -0.150901  1.000000 -0.022439  0.185145 -0.249720 -0.480481
# color   -0.001267  0.292400 -0.022439  1.000000  0.088333  0.035517  0.034978
# clarity -0.003441 -0.348611  0.185145  0.088333  1.000000 -0.060720 -0.184567
# depth    0.002647  0.027852 -0.249720  0.035517 -0.060720  1.000000 -0.230631
# table    0.002448  0.225737 -0.480481  0.034978 -0.184567 -0.230631  1.000000
# x       -0.000404  0.980751 -0.146917  0.269392 -0.375553 -0.010648  0.237742
# y       -0.000415  0.980288 -0.147299  0.269496 -0.373778 -0.011542  0.233409
# z        0.000107  0.975416 -0.168659  0.270428 -0.376921  0.081717  0.212694
# price   -0.001392  0.943396 -0.090948  0.210859 -0.184439  0.001880  0.174915
#
# ...

# %%
sns.lineplot(y=df['price'],x=df['x'])
# Out:
# <Axes: xlabel='x', ylabel='price'>

# %%
sns.lineplot(y=df['price'],x=df['y'])
# Out:
# <Axes: xlabel='y', ylabel='price'>

# %%
sns.lineplot(y=df['price'],x=df['z'])
# Out:
# <Axes: xlabel='z', ylabel='price'>

# %%
sns.heatmap(df[[i for i in l]].corr(),annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
